# %% [markdown]
# <a href="https://colab.research.google.com/github/ylmgrbzz/Machine-Learning-Projects-With-DecisionTreeClassifier-And-RandomForestClassifier/blob/main/Pokemon_Winner_Prediction_With_DecisionTreeClassifier_And_RandomForestClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.tree import DecisionTreeClassifier,export_graphviz
import numpy as np
import matplotlib.pyplot as plt
import graphviz
from sklearn.ensemble import RandomForestClassifier

# %%
poke=pd.read_csv("pokemon.csv")

# %%
poke.head(3)
# Out:
#    First_pokemon  Second_pokemon  Winner
# 0            266             298     298
# 1            702             701     701
# 2            191             668     668

# %%
poke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   First_pokemon   50000 non-null  int64
#  1   Second_pokemon  50000 non-null  int64
#  2   Winner          50000 non-null  int64
# dtypes: int64(3)
# memory usage: 1.1 MB

# %%
len(poke['First_pokemon'].unique())
# Out:
# 784

# %%
(784*783)/2
# Out:
# 306936.0

# %%
poke["Winner"]=poke["First_pokemon"]==poke["Winner"]

# %%
poke.head(4)
# Out:
#    First_pokemon  Second_pokemon  Winner
# 0            266             298   False
# 1            702             701   False
# 2            191             668   False
# 3            237             683   False

# %%
poke["Winner"]=np.where(poke["Winner"],0,1)

# %%
poke.head(30)
# Out:
#     First_pokemon  Second_pokemon  Winner
# 0             266             298       1
# 1             702             701       1
# 2             191             668       1
# 3             237             683       1
# 4             151             231       0
# 5             657             752       0
# 6             192             134       1
# 7              73             545       1
# 8             220             763       1
# 9             302              31       1
# 10            442             130       1
# 11            701             624       0
# 12             15             283       1
# 13            151              87       0
# 14            269             462       0
# 15            763             448       1
# 16            143             263       1
# 17            365             240       1
# 18            499             774       0
# 19            563             578       0
# 20            440             687       1
# ...

# %%
y=poke[["Winner"]]
x=poke.drop("Winner",axis=1)

# %%
x_train,x_test,y_train, y_test= train_test_split(x,y,test_size=0.95,random_state=21)

# %%
tree=DecisionTreeClassifier()
model=tree.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.5812

# %%
tree=DecisionTreeClassifier()
model=tree.fit(x,y)
model.score(x,y)
# Out:
# 1.0

# %%
x_train
# Out:
#        First_pokemon  Second_pokemon
# 25379             77             638
# 29068            620             427
# 29785            754             353
# 38717            152             753
# 48004            474             298
# ...              ...             ...
# 16432            488             725
# 8964             590             304
# 5944             508             291
# 5327             602             681
# 15305            406             737
#
# [2500 rows x 2 columns]

# %%
rf=RandomForestClassifier(n_estimators=300)
model=rf.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 0.6120210526315789

# %%
pokemon1=pd.read_csv('pokemon1.csv')

# %%
pokemon1.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
poke.head(3)
# Out:
#    First_pokemon  Second_pokemon  Winner
# 0            266             298       1
# 1            702             701       1
# 2            191             668       1

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=10,train_size=0.95)

# %%
rf=RandomForestClassifier(n_estimators=200)
model=rf.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 0.7232

# %%
model.predict([[156,90]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# array([0])

# %%
pokemon1=pokemon1.set_index('Name')

# %%
pokemon1.head(3)
# Out:
#            # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur  1  Grass  Poison  45      49       49       65       65     45
# Ivysaur    2  Grass  Poison  60      62       63       80       80     60
# Venusaur   3  Grass  Poison  80      82       83      100      100     80
#
#            Generation  Legendary
# Name
# Bulbasaur           1      False
# Ivysaur             1      False
# Venusaur            1      False

# %%
pokemon1.loc['Venusaur']["#"]
# Out:
# 3

# %%
def fight(p1,p2):
    id1=pokemon.loc[p1]["#"]
    id2=pokemon.loc[p2]["#"]
    sonuc=model.predict([[id1,id2]])
    if sonuc[0]==0:
        kazanan=p1
    else:
        kazanan=p2
    return kazanan

# %%
fight('Venusaur','Pikachu')
